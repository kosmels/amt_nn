# %%
import numpy as np
import matplotlib.pyplot as plt
import librosa, librosa.display
import import_ipynb
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.layers import (Conv2D,
                                     Conv1D,
                                     MaxPooling2D,
                                     Flatten,
                                     Dense,
                                     Dropout,
                                     Lambda,
                                     Reshape,
                                     Permute)
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.utils import plot_model

# %%
import preprocessing as prep
import constants as c

# %%
def conv2d_reshape(cqt_matrices, midi_matrices):
    """
    Transpose both matrices (spectrogram and MIDI one-hot) to be in format [frames, frequency_bins/one-hot]
    and reshape given wav matrices into the right input shape for Keras Conv2D network: (batch, rows, cols, channels)
    
    Args:
    wav_matrices: array of CQT spectrograms (splitted into frames)
    midi_matrices: labels for frames, represented as one-hot vectors
    
    Return:
    Concatenated arrays of spectrograms and labels, which are used as input for neural network
    """
    
    cqt_reshaped = [np.array(cqt_chunk) for cqt_chunk in cqt_matrices]
    cqt_reshaped = np.concatenate(cqt_reshaped)
    cqt_reshaped = np.array([cqt.T for cqt in cqt_reshaped])
    cqt_reshaped = np.array([cqt.reshape(2*c.CHUNK_PADDING, c.BINS_NUMBER, 1) for cqt in cqt_reshaped])
    
    midi_reshaped = [midi_chunk.T for midi_chunk in midi_matrices]
    midi_reshaped = np.concatenate(midi_reshaped)  
    
    return cqt_reshaped, midi_reshaped

def create_conv_model(input_heigth, input_width, num_classes):
    """
    Create convolutional acoustic model inspired by Kelz 2016
    Paper: On The Potential Of Simple Framewise Approaches To Piano Transcription
    
    (Sequential) Model created using Keras high-level API: https://www.tensorflow.org/guide/keras
    
    Args:
    input_height/input_width: input parameters defining model shape
    num_classes: number of model output classes in Dense layer
    
    """
    
    input_shape = (input_heigth, input_width, 1)
    
    model = Sequential()
    model.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='valid', input_shape=input_shape))
    model.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='valid'))
    model.add(MaxPooling2D(pool_size=(1, 2), strides=(1, 2), padding='same'))
    model.add(Dropout(0.25))
    model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='valid'))
    model.add(MaxPooling2D(pool_size=(1, 2), strides=(1, 2), padding='same'))
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(num_classes, activation='sigmoid'))
    adam_opt = Adam(lr=0.0001, decay=1e-5)
    model.compile(loss='binary_crossentropy',
                  optimizer=adam_opt)
    return model

def create_classic_conv_model(input_heigth, input_width):
    """
    Create convolutional acoustic model for sequence predictions.
    
    Args:
    input_height/input_width: input parameters defining model shape

    Return:
    tf.keras.Model object with specific 
    input (batch, input_height, input_width, 1),
    output (batch, classes, width) shapes.
    """ 
    
    from tensorflow.keras.layers import Input
    
    inputs = Input(shape=(input_heigth, input_width, 1))
    model = Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='valid')(inputs)
    model = Conv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same')(model)
    model = MaxPooling2D(pool_size=(1, 2), strides=(1, 2), padding='valid')(model)
    model = Dropout(0.25)(model)
    model = Conv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='valid')(model)
    model = MaxPooling2D(pool_size=(1, 2), strides=(1, 2), padding='valid')(model)
    model = Dropout(0.25)(model)
    
    shapes = model.shape
    model = Reshape((shapes[1], shapes[2].value * shapes[3].value))(model)
#     print(model.output_shape[0])
#     outputs = tf.reshape(model, (shapes[0], shapes[1], shapes[2] * shapes[3]))
#     outputs = Lambda(lambda x: tf.keras.backend.reshape(x, (shapes[0], shapes[1], shapes[2].value*shapes[3].value)))(model)
    outputs = Conv1D(filters=88, kernel_size=1, activation='sigmoid', padding='valid')(model)
#     outputs = Lambda(lambda x: tf.transpose(x, [0,2,1]))(model)
#     model = Conv2D(filters=128, kernel_size=(1, 1), strides=(3, 1), activation='relu', padding='valid')(model)
#     model = Conv2D(filters=256, kernel_size=(1, 1), strides=(3, 1), activation='relu', padding='valid')(model)
#     model = Conv2D(filters=512, kernel_size=(1, 1), strides=(3, 1), activation='relu', padding='valid')(model)
#     model = Conv2D(filters=88, kernel_size=(1, 1), strides=(3, 1), activation='relu', padding='valid')(model)
#     model = Lambda(lambda x: tf.keras.backend.squeeze(x, 1))(model)
#     outputs = Lambda(lambda x: tf.transpose(x, [0,2,1]))(model)
    
    return tf.keras.Model(inputs, outputs)
    

def train_model(cqt_train, cqt_test, midi_train, midi_test, n_classes=88):    
    height, width, depth = cqt_train[0].shape
    epochs = 5
    
    model = create_conv_model(height, width, n_classes)
    history = model.fit(cqt_train, midi_train, validation_data=(cqt_test, midi_test), epochs=epochs, batch_size=64)
    
    # Evaulation of accuracy and loss history
    # Inspiration from: https://machinelearningmastery.com/display-deep-learning-model-training-history-in-keras/
    plt.plot(history.history['acc'])
    plt.plot(history.history['val_acc'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    
    return model

def generator_train_model(dataset, n_classes=88):    
    height, width = c.BINS_NUMBER, c.SEQUENCE_CHUNK_LENGTH + 2*c.CHUNK_PADDING
    epochs = 5
    
    model = create_conv_model(height, width, n_classes)
    model.summary()
    history = model.fit(dataset.make_one_shot_iterator(), steps_per_epoch=2)
    
    # Evaulation of accuracy and loss history
    # Inspiration from: https://machinelearningmastery.com/display-deep-learning-model-training-history-in-keras/
    plt.plot(history.history['acc'])
    plt.plot(history.history['val_acc'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    
    return model

# %%
train_dataset, valid_dataset, test_dataset = prep.get_dataset()
# Out:
# WARNING:tensorflow:From c:\users\silvopc\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:429: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, use
#     tf.py_function, which takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.

# %%
adam_opt = Adam(lr=0.0001, decay=1e-5)
print("Input shapes:", c.SEQUENCE_CHUNK_LENGTH + 2*c.CHUNK_PADDING, c.BINS_NUMBER)
model = create_classic_conv_model(c.SEQUENCE_CHUNK_LENGTH + 2*c.CHUNK_PADDING, c.BINS_NUMBER)
model.summary()
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
model.fit(train_dataset.make_one_shot_iterator(),
          validation_data=valid_dataset.make_one_shot_iterator(),
          validation_steps=5,
          epochs=3,
          steps_per_epoch=20,
          verbose=1
         )
# history = model.evaluate_generator(test_dataset.make_one_shot_iterator(), steps=10)
# Out:
# Input shapes: 629 264
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 629, 264, 1)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 627, 262, 32)      320
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 627, 262, 64)      18496
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 627, 131, 64)      0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 627, 131, 64)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 625, 129, 64)      36928
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 625, 64, 64)       0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 625, 64, 64)       0
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 625, 4096)         0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 625, 88)           360536
# =================================================================
# Total params: 416,280
# Trainable params: 416,280
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From c:\users\silvopc\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Aligning single pair of CQT spectrogram and MIDI matrix
# Both matrices aligned to 7752 frames.
# Currently processed  12 sequences.
# Aligning single pair of CQT spectrogram and MIDI matrix
# Both matrices aligned to 7064 frames.
# Currently processed  23 sequences.
# Aligning single pair of CQT spectrogram and MIDI matrix
# Both matrices aligned to 5945 frames.
# Currently processed  32 sequences.
# Aligning single pair of CQT spectrogram and MIDI matrix
# Both matrices aligned to 16079 frames.
# Currently processed  57 sequences.
#  3/10 [========>.....................] - ETA: 4:52 - loss: 0.6405 - acc: 0.7899Aligning single pair of CQT spectrogram and MIDI matrix
# Both matrices aligned to 1785 frames.
# Currently processed  59 sequences.
# Aligning single pair of CQT spectrogram and MIDI matrix
# Both matrices aligned to 4796 frames.
# Currently processed  66 sequences.
#  4/10 [===========>..................] - ETA: 3:49 - loss: 0.5938 - acc: 0.8328Aligning single pair of CQT spectrogram and MIDI matrix
# Both matrices aligned to 975 frames.
# Currently processed  67 sequences.
# Aligning single pair of CQT spectrogram and MIDI matrix
# Both matrices aligned to 3850 frames.
# Currently processed  73 sequences.
#  5/10 [==============>...............] - ETA: 2:55 - loss: 0.5388 - acc: 0.8599Aligning single pair of CQT spectrogram and MIDI matrix
# Both matrices aligned to 1613 frames.
# Currently processed  75 sequences.
# Aligning single pair of CQT spectrogram and MIDI matrix
# Both matrices aligned to 2785 frames.
# Currently processed  79 sequences.
# Aligning single pair of CQT spectrogram and MIDI matrix
# Both matrices aligned to 2789 frames.
# Currently processed  83 sequences.
#  6/10 [=================>............] - ETA: 2:26 - loss: 0.4845 - acc: 0.8776Aligning single pair of CQT spectrogram and MIDI matrix
# Both matrices aligned to 8839 frames.
# Currently processed  97 sequences.
#  8/10 [=======================>......] - ETA: 1:18 - loss: 0.4023 - acc: 0.8997Aligning single pair of CQT spectrogram and MIDI matrix
# Both matrices aligned to 4581 frames.
# Currently processed  104 sequences.
#  9/10 [==========================>...] - ETA: 37s - loss: 0.3750 - acc: 0.9081 Aligning single pair of CQT spectrogram and MIDI matrix
# Both matrices aligned to 3388 frames.
# Currently processed  109 sequences.
# Aligning single pair of CQT spectrogram and MIDI matrix
# Both matrices aligned to 4797 frames.
# Currently processed  116 sequences.
# Aligning single pair of CQT spectrogram and MIDI matrix
# Both matrices aligned to 7636 frames.
# Currently processed  12 sequences.
# Aligning single pair of CQT spectrogram and MIDI matrix
# Both matrices aligned to 11327 frames.
# Currently processed  30 sequences.
# Aligning single pair of CQT spectrogram and MIDI matrix
# Both matrices aligned to 2436 frames.
# Currently processed  33 sequences.
# Aligning single pair of CQT spectrogram and MIDI matrix
# Both matrices aligned to 3388 frames.
# Currently processed  38 sequences.
# Aligning single pair of CQT spectrogram and MIDI matrix
# Both matrices aligned to 16079 frames.
# Currently processed  63 sequences.
# Aligning single pair of CQT spectrogram and MIDI matrix
# Both matrices aligned to 18108 frames.
# Currently processed  91 sequences.
# 10/10 [==============================] - 564s 56s/step - loss: 0.3556 - acc: 0.9143 - val_loss: 0.2346 - val_acc: 0.9651

# %%
it = test_dataset.make_initializable_iterator()
cqt_batch = []
midi_batch = []
el = it.get_next()
with tf.Session() as sess:
    sess.run(it.initializer)

    for i in range(20):
        c, m = sess.run(el)
        cqt_batch.append(c)
        midi_batch.append(m)

model.test_on_batch(np.array(cqt_batch),np.array(midi_batch))
# model.evaluate_generator(generator=test_dataset.make_one_shot_iterator(), steps=5)
# Out:
# Aligning single pair of CQT spectrogram and MIDI matrix
# Both matrices aligned to 11997 frames.
# Currently processed  19 sequences.
# Aligning single pair of CQT spectrogram and MIDI matrix
# Both matrices aligned to 867 frames.
# Currently processed  20 sequences.
# [0.21163973, 0.9653373]

# %%
model.metrics_names
# Out:
# ['loss', 'acc']

# %%
predictions = model.predict(np.array(cqt_batch))

# %%
x = np.concatenate(predictions, axis=0)
x.shape
prep.mp.plot_piano_roll(x.T)

# %%
ws2 = np.array(prep.wav_chunks[0])
wavs_reshaped2 = np.array([w.T for w in ws2])
wsr2 = np.array([w.reshape(4, 264, 1) for w in wavs_reshaped2])
msr2 = prep.midi_chunks[0].T

# %%
midi_predicted = model.predict(cqt_m)

# %%
midi_predicted = midi_predicted.T

# %%
prep.mp.plot_piano_roll(midi_predicted[:,:])

# %%
midi_m = prep.pretty_midi.PrettyMIDI('D:\School\Bc\model\MAPS\AkPnBcht\MUS\MAPS_MUS-scn16_2_AkPnBcht.mid')
midi_m = midi_m.get_piano_roll(fs=c.FRAME_LENGTH)[c.MIDI_MIN:c.MIDI_MAX+1, :]
prep.mp.plot_piano_roll(midi_m)

# %%
# cqt_m = prep.ap.cqt_matrix('D:\School\Bc\model\MAPS\AkPnBsdf\MUS\MAPS_MUS-alb_se3_AkPnBsdf.wav')
cqt_m = prep.ap.cqt_matrix('D:\School\Bc\model\MAPS\AkPnBcht\MUS\MAPS_MUS-chpn-p8_AkPnBcht.wav')
cqt_m = prep.log_normalization(cqt_m)

# %%
midi_m = prep.mp.load_midi_file('D:\School\Bc\model\MAPS\AkPnBcht\MUS\MAPS_MUS-chpn-p8_AkPnBcht.mid')
midi_m = prep.mp.pretty_midi_to_frame_matrix(midi_m)
midi_m = prep.mp.midi_split_to_sequence(midi_m)

# %%
cqt_m = prep.ap.cqt_split_to_sequence(cqt_m)

# %%
input_sequence = np.array(cqt_m[:2])
input_sequence = np.array([x.T for x in input_sequence])
input_sequence = np.array([x.reshape(*x.shape, -1) for x in input_sequence])
input_sequence.shape
# Out:
# (2, 629, 264, 1)

# %%
midi_predicted = model.predict(input_sequence)

# %%
cqt_m[1].shape
# Out:
# (264, 629)

# %%
prep.ap.create_spectrogram(input_sequence[0][:,:,0].T)
# input_sequence[0][:,:,0].T

# %%
for midi, cqt, midi_o in zip(midi_predicted, cqt_m[:2], midi_m[:2]):
    print(midi.shape)
    prep.mp.plot_piano_roll(midi.T)
    prep.mp.plot_piano_roll(midi_o)
    prep.ap.create_spectrogram(cqt)
# Out:
# (625, 88)
# (625, 88)

# %%
midi_truncated = [[0 if x < 0.07 else 1 for x in midi] for midi in midi_predicted[0]]

# %%
prep.mp.plot_piano_roll(np.array(midi_truncated))

# %%
prep.ap.create_spectrogram(cqt_m[0])
