# %%
import numpy as np
import matplotlib.pyplot as plt
import librosa, librosa.display
import import_ipynb
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.layers import (Conv2D, MaxPooling2D, Flatten, Dense, Dropout)
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import SGD, Adam

tf.reset_default_graph()

# %%
import preprocessing as prep
import constants as c
# Out:
# importing Jupyter notebook from preprocessing.ipynb
# importing Jupyter notebook from audio_prep.ipynb
# importing Jupyter notebook from constants.ipynb
# importing Jupyter notebook from midi_prep.ipynb
# Loading  30 files.
# Successfully loaded  3  file(s)
# Loading successfull!

# %%
def conv2d_reshape(wav_matrices, midi_matrices):
    """
    Transpose both matrices (spectrogram and MIDI one-hot) to be in format [frames, frequency_bins/one-hot]
    and reshape given wav matrices into the right input shape for Keras Conv2D network: (batch, rows, cols, channels)
    
    Args:
    wav_matrices: array of CQT spectrograms (splitted into frames)
    midi_matrices: labels for frames, represented as one-hot vectors
    
    Return:
    Concatenated arrays of spectrograms and labels, which are used as input for neural network
    """
    
    wavs_reshaped = [np.array(wav_chunk) for wav_chunk in wav_matrices]
    wavs_reshaped = np.concatenate(wavs_reshaped)
    wavs_reshaped = np.array([wav.T for wav in wavs_reshaped])
    wavs_reshaped = np.array([wav.reshape(2*c.FRAME_SLICE, c.BINS_NUMBER, 1) for wav in wavs_reshaped])
    
    midi_reshaped = [midi_chunk.T for midi_chunk in midi_matrices]
    midi_reshaped = np.concatenate(midi_reshaped)  
    
    return wavs_reshaped, midi_reshaped

def create_model(input_heigth, input_width, num_classes):
    """
    Create convolutional acoustic model inspired by Kelz 2016
    Paper: On The Potential Of Simple Framewise Approaches To Piano Transcription
    
    Model created using Keras high-level API: https://www.tensorflow.org/guide/keras
    """
    
    input_shape = (input_heigth, input_width, 1)
    
    model = Sequential()
    model.add(Conv2D(filters=48, kernel_size=(3, 3), activation='relu', padding='same', input_shape=input_shape))
    model.add(Conv2D(filters=48, kernel_size=(3, 3), activation='relu', padding='same'))
    model.add(MaxPooling2D(pool_size=(1, 2), strides=(1, 2), padding='same'))
    model.add(Dropout(0.25))
    model.add(Conv2D(filters=96, kernel_size=(3, 3), activation='relu', padding='same'))
    model.add(MaxPooling2D(pool_size=(1, 2), strides=(1, 2), padding='same'))
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(num_classes, activation='sigmoid'))
    adam_opt = Adam(lr=0.0001, decay=1e-5)
    model.compile(loss='binary_crossentropy',
                  optimizer=adam_opt,
                  metrics=['acc'])
    return model

def train_model(cqt_train, cqt_test, midi_train, midi_test, n_classes=88):    
    height, width, depth = cqt_train[0].shape
    epochs = 10
    
    model = create_model(height, width, n_classes)
    history = model.fit(cqt_train, midi_train, validation_data=(cqt_test, midi_test), epochs=epochs, batch_size=64)
    
    # Evaulation of accuracy and loss history
    # Inspiration from: https://machinelearningmastery.com/display-deep-learning-model-training-history-in-keras/
    plt.plot(history.history['acc'])
    plt.plot(history.history['val_acc'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    
    return model

# %%
wsr, msr = conv2d_reshape(prep.wav_chunks, prep.midi_chunks)
x_train, x_test, y_train, y_test = train_test_split(wsr, msr, test_size=0.2, random_state=21)

# %%
model = train_model(x_train, x_test, y_train, y_test)
# Out:
# Train on 22879 samples, validate on 5720 samples
# Epoch 1/10
# 22879/22879 [==============================] - 272s 12ms/step - loss: 0.1207 - acc: 0.9667 - val_loss: 0.0540 - val_acc: 0.9806
# Epoch 2/10
# 22879/22879 [==============================] - 273s 12ms/step - loss: 0.0434 - acc: 0.9836 - val_loss: 0.0349 - val_acc: 0.9874
# Epoch 3/10
# 22879/22879 [==============================] - 219s 10ms/step - loss: 0.0321 - acc: 0.9879 - val_loss: 0.0272 - val_acc: 0.9902
# Epoch 4/10
# 22879/22879 [==============================] - 211s 9ms/step - loss: 0.0258 - acc: 0.9903 - val_loss: 0.0228 - val_acc: 0.9917
# Epoch 5/10
# 22879/22879 [==============================] - 210s 9ms/step - loss: 0.0219 - acc: 0.9918 - val_loss: 0.0196 - val_acc: 0.9929
# Epoch 6/10
# 22879/22879 [==============================] - 211s 9ms/step - loss: 0.0193 - acc: 0.9929 - val_loss: 0.0177 - val_acc: 0.9936
# Epoch 7/10
# 22879/22879 [==============================] - 260s 11ms/step - loss: 0.0175 - acc: 0.9935 - val_loss: 0.0160 - val_acc: 0.9943
# Epoch 8/10
# 22879/22879 [==============================] - 277s 12ms/step - loss: 0.0159 - acc: 0.9941 - val_loss: 0.0152 - val_acc: 0.9946
# Epoch 9/10
# 22879/22879 [==============================] - 298s 13ms/step - loss: 0.0148 - acc: 0.9946 - val_loss: 0.0134 - val_acc: 0.9951
# Epoch 10/10
# 22879/22879 [==============================] - 278s 12ms/step - loss: 0.0136 - acc: 0.9950 - val_loss: 0.0128 - val_acc: 0.9955

# %%
ws2 = np.array(prep.wav_chunks[0])
wavs_reshaped2 = np.array([w.T for w in ws2])
wsr2 = np.array([w.reshape(4, 264, 1) for w in wavs_reshaped2])
msr2 = prep.midi_chunks[0].T

# %%
midi_predicted = model.predict(wsr2)

# %%
midi_predicted = midi_predicted.T

# %%
prep.mp.plot_piano_roll(midi_predicted[:,:])

# %%
midi_m = prep.pretty_midi.PrettyMIDI('D:\School\Bc\model\MAPS\AkPnBcht\MUS\MAPS_MUS-scn16_2_AkPnBcht.mid')
midi_m = midi_m.get_piano_roll(fs=c.FRAMES_PER_SEC)[c.MIDI_MIN:c.MIDI_MAX+1, :]
prep.mp.plot_piano_roll(midi_m)

# %%
cqt_m = prep.ap.cqt_matrix('D:\School\Bc\model\MAPS\AkPnBcht\MUS\MAPS_MUS-scn16_2_AkPnBcht.wav')

# %%
cqt_m = prep.ap.split_wav(cqt_m)

# %%
cqt_m = np.array([np.array(w).T for w in cqt_m])
cqt_m = np.array([w.reshape(4, 264, 1) for w in cqt_m])
cqt_m.shape
# Out:
# (19046, 4, 264, 1)

# %%
mid_trunc = np.array([[0 if x < 0.35 else 1 for x in m] for m in midi_predicted])

# %%
mid_trunc.shape
# Out:
# (88, 10679)
